# %% [markdown]
# # 使用手寫辨識資料集, 觀察 PCA 算法

# %% [markdown]
# # [教學目標]
# - 以 PCA + 邏輯斯迴歸判斷手寫辨識資料集, 觀察不同 component 下正確率的變化
# - 因為非監督模型的效果, 較難以簡單的範例看出來
#   所以非監督偶數日提供的範例與作業, 主要目的在於觀察非監督模型的效果,
#   同學只要能感受到模型效果即可, 不用執著於搞懂程式的每一個部分

# %% [markdown]
# # [範例重點]
# - 以手寫辨識資料集, 觀察 PCA 算法取不同 component 時, PCA 解釋度與分類正確率如何變化 (In[5], Out[5])

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")

# %%
# 定義 PCA 與隨後的邏輯斯迴歸函數
logistic = SGDClassifier(loss='log', penalty='l2', max_iter=10000, tol=1e-5, random_state=0)
pca = PCA()
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

# 載入手寫數字辨識集
digits = datasets.load_digits()
X_digits = digits.data
y_digits = digits.target

# %%
# 先執行 GridSearchCV 跑出最佳參數
param_grid = {
    'pca__n_components': [4, 10, 20, 30, 40, 50, 64],
    'logistic__alpha': np.logspace(-4, 4, 5),
}
search = GridSearchCV(pipe, param_grid, iid=False, cv=5, return_train_score=False)
search.fit(X_digits, y_digits)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.915):
# {'logistic__alpha': 0.01, 'pca__n_components': 64}

# %%
# 繪製不同 components 的 PCA 解釋度
pca.fit(X_digits)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(pca.explained_variance_ratio_, linewidth=2)
ax0.set_ylabel('PCA explained variance')

ax0.axvline(search.best_estimator_.named_steps['pca'].n_components, linestyle=':', label='n_components chosen')
ax0.legend(prop=dict(size=12))
# 繪製不同採樣點的分類正確率
results = pd.DataFrame(search.cv_results_)
components_col = 'param_pca__n_components'
best_clfs = results.groupby(components_col).apply(lambda g: g.nlargest(1, 'mean_test_score'))

best_clfs.plot(x=components_col, y='mean_test_score', yerr='std_test_score', legend=False, ax=ax1)
ax1.set_ylabel('Classification accuracy (val)')
ax1.set_xlabel('n_components')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 觀察結果
# * explained variance ratio : 解釋變異性隨著 components 穩定下降
# * 分類預測準確率 : 似乎也隨著 components 提升, 但是在 20 以後提升不多

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.084968      0.021294         0.000573        0.000015
# 1        0.043311      0.002726         0.000677        0.000160
# 2        0.054658      0.005680         0.000593        0.000011
# 3        0.066271      0.008968         0.001327        0.001406
# 4        0.067116      0.004104         0.000627        0.000014
# 5        0.082521      0.009569         0.001073        0.000842
# 6        0.090218      0.003457         0.000747        0.000135
# 7        2.093822      0.676934         0.000627        0.000174
# 8        0.055998      0.009148         0.000600        0.000021
# 9        0.076408      0.007002         0.000591        0.000016
# 10       0.098574      0.006823         0.000609        0.000018
# 11       0.107592      0.009005         0.000626        0.000012
# 12       0.123990      0.012593         0.000740        0.000136
# 13       0.142816      0.021847         0.000751        0.000015
# 14       0.499446      0.039682         0.000602        0.000113
# 15       0.587970      0.043643         0.000621        0.000083
# 16       0.776630      0.080176         0.000731        0.000036
# 17       0.940737      0.096661         0.000815        0.000110
# 18       1.105638      0.101506         0.000774        0.000049
# 19       1.293100      0.112423         0.000786        0.000046
# 20       1.537848      0.135599         0.000950        0.000198
# 21       0.292012      0.011359         0.000575        0.000054
# 22       0.356600      0.012671         0.000622        0.000094
# 23       0.465946      0.019958         0.000725        0.000007
# 24       0.591492      0.042804         0.000764        0.000053
# 25       0.681325      0.030992         0.000746        0.000012
# 26       0.783626      0.036255         0.000768        0.000017
# 27       0.925434      0.037989         0.000823        0.000043
# 28       0.021242      0.000722         0.000552        0.000011
# 29       0.035551      0.006460         0.000642        0.000086
# 30       0.055688      0.050047         0.000585        0.000012
# 31       0.036991      0.000372         0.000624        0.000039
# 32       0.044048      0.001271         0.000590        0.000011
# 33       0.051552      0.002665         0.000626        0.000011
# 34       0.051410      0.000902         0.000702        0.000123
#
#    param_logistic__alpha param_pca__n_components  \
# 0                 0.0001                       4
# 1                 0.0001                      10
# 2                 0.0001                      20
# 3                 0.0001                      30
# 4                 0.0001                      40
# 5                 0.0001                      50
# 6                 0.0001                      64
# 7                   0.01                       4
# 8                   0.01                      10
# 9                   0.01                      20
# 10                  0.01                      30
# 11                  0.01                      40
# 12                  0.01                      50
# 13                  0.01                      64
# 14                     1                       4
# 15                     1                      10
# 16                     1                      20
# 17                     1                      30
# 18                     1                      40
# 19                     1                      50
# 20                     1                      64
# 21                   100                       4
# 22                   100                      10
# 23                   100                      20
# 24                   100                      30
# 25                   100                      40
# 26                   100                      50
# 27                   100                      64
# 28                 10000                       4
# 29                 10000                      10
# 30                 10000                      20
# 31                 10000                      30
# 32                 10000                      40
# 33                 10000                      50
# 34                 10000                      64
#
#                                                params  split0_test_score  \
# 0   {'logistic__alpha': 0.0001, 'pca__n_components...           0.702778
# 1   {'logistic__alpha': 0.0001, 'pca__n_components...           0.913889
# 2   {'logistic__alpha': 0.0001, 'pca__n_components...           0.919444
# 3   {'logistic__alpha': 0.0001, 'pca__n_components...           0.916667
# 4   {'logistic__alpha': 0.0001, 'pca__n_components...           0.908333
# 5   {'logistic__alpha': 0.0001, 'pca__n_components...           0.908333
# 6   {'logistic__alpha': 0.0001, 'pca__n_components...           0.911111
# 7   {'logistic__alpha': 0.01, 'pca__n_components': 4}           0.730556
# 8   {'logistic__alpha': 0.01, 'pca__n_components':...           0.902778
# 9   {'logistic__alpha': 0.01, 'pca__n_components':...           0.925000
# 10  {'logistic__alpha': 0.01, 'pca__n_components':...           0.927778
# 11  {'logistic__alpha': 0.01, 'pca__n_components':...           0.919444
# 12  {'logistic__alpha': 0.01, 'pca__n_components':...           0.925000
# 13  {'logistic__alpha': 0.01, 'pca__n_components':...           0.922222
# 14   {'logistic__alpha': 1.0, 'pca__n_components': 4}           0.675000
# 15  {'logistic__alpha': 1.0, 'pca__n_components': 10}           0.897222
# 16  {'logistic__alpha': 1.0, 'pca__n_components': 20}           0.922222
# 17  {'logistic__alpha': 1.0, 'pca__n_components': 30}           0.930556
# 18  {'logistic__alpha': 1.0, 'pca__n_components': 40}           0.938889
# 19  {'logistic__alpha': 1.0, 'pca__n_components': 50}           0.936111
# 20  {'logistic__alpha': 1.0, 'pca__n_components': 64}           0.936111
# 21  {'logistic__alpha': 100.0, 'pca__n_components'...           0.388889
# 22  {'logistic__alpha': 100.0, 'pca__n_components'...           0.636111
# 23  {'logistic__alpha': 100.0, 'pca__n_components'...           0.647222
# 24  {'logistic__alpha': 100.0, 'pca__n_components'...           0.644444
# 25  {'logistic__alpha': 100.0, 'pca__n_components'...           0.644444
# 26  {'logistic__alpha': 100.0, 'pca__n_components'...           0.644444
# 27  {'logistic__alpha': 100.0, 'pca__n_components'...           0.644444
# 28  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 29  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 30  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 31  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 32  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 33  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
# 34  {'logistic__alpha': 10000.0, 'pca__n_component...           0.202778
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.583333           0.679666           0.727019
# 1            0.841667           0.894150           0.910864
# 2            0.877778           0.908078           0.941504
# 3            0.877778           0.913649           0.955432
# 4            0.880556           0.924791           0.949861
# 5            0.880556           0.935933           0.949861
# 6            0.869444           0.933148           0.952646
# 7            0.663889           0.732591           0.738162
# 8            0.844444           0.891365           0.908078
# 9            0.869444           0.910864           0.941504
# 10           0.891667           0.924791           0.955432
# 11           0.886111           0.930362           0.952646
# 12           0.894444           0.947075           0.944290
# 13           0.891667           0.949861           0.947075
# 14           0.663889           0.721448           0.749304
# 15           0.825000           0.883008           0.916435
# 16           0.852778           0.910864           0.947075
# 17           0.875000           0.927577           0.958217
# 18           0.886111           0.919220           0.961003
# 19           0.877778           0.922006           0.958217
# 20           0.877778           0.922006           0.958217
# 21           0.350000           0.520891           0.718663
# 22           0.583333           0.768802           0.857939
# 23           0.594444           0.771588           0.885794
# 24           0.600000           0.777159           0.891365
# 25           0.602778           0.777159           0.891365
# 26           0.602778           0.777159           0.891365
# 27           0.602778           0.777159           0.891365
# 28           0.194444           0.103064           0.715877
# 29           0.197222           0.103064           0.852368
# 30           0.197222           0.103064           0.863510
# 31           0.197222           0.103064           0.866295
# 32           0.197222           0.103064           0.866295
# 33           0.197222           0.103064           0.863510
# 34           0.197222           0.103064           0.863510
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.685237         0.675607        0.049000               27
# 1            0.832869         0.878688        0.034593               16
# 2            0.885794         0.906520        0.023018               13
# 3            0.877437         0.908193        0.028997               12
# 4            0.885794         0.909867        0.025547                9
# 5            0.883008         0.911538        0.027741                7
# 6            0.877437         0.908757        0.031790               11
# 7            0.690808         0.711201        0.029029               25
# 8            0.824513         0.874236        0.033506               18
# 9            0.866295         0.902621        0.030003               14
# 10           0.866295         0.913193        0.030965                4
# 11           0.869081         0.911529        0.030186                8
# 12           0.863510         0.914864        0.031813                2
# 13           0.866295         0.915424        0.032286                1
# 14           0.665738         0.695076        0.034271               26
# 15           0.860724         0.876478        0.031520               17
# 16           0.855153         0.897618        0.037525               15
# 17           0.857939         0.909858        0.037394               10
# 18           0.866295         0.914304        0.034377                3
# 19           0.866295         0.912081        0.034864                5
# 20           0.866295         0.912081        0.034864                5
# 21           0.623955         0.520480        0.138826               28
# 22           0.799443         0.729126        0.102974               24
# 23           0.830084         0.745826        0.109538               23
# 24           0.824513         0.747496        0.109439               22
# 25           0.824513         0.748052        0.108693               19
# 26           0.824513         0.748052        0.108693               19
# 27           0.824513         0.748052        0.108693               19
# 28           0.615599         0.366353        0.248966               35
# 29           0.779944         0.427075        0.320473               34
# 30           0.802228         0.433760        0.328365               33
# 31           0.805014         0.434875        0.329719               30
# 32           0.810585         0.435989        0.330975               29
# 33           0.805014         0.434318        0.328991               31
# 34           0.805014         0.434318        0.328991               31

# %%
best_clfs
# Out:
#                             mean_fit_time  std_fit_time  mean_score_time  \
# param_pca__n_components
# 4                       7        2.093822      0.676934         0.000627
# 10                      1        0.043311      0.002726         0.000677
# 20                      2        0.054658      0.005680         0.000593
# 30                      10       0.098574      0.006823         0.000609
# 40                      18       1.105638      0.101506         0.000774
# 50                      12       0.123990      0.012593         0.000740
# 64                      13       0.142816      0.021847         0.000751
#
#                             std_score_time param_logistic__alpha  \
# param_pca__n_components
# 4                       7         0.000174                  0.01
# 10                      1         0.000160                0.0001
# 20                      2         0.000011                0.0001
# 30                      10        0.000018                  0.01
# 40                      18        0.000049                     1
# 50                      12        0.000136                  0.01
# 64                      13        0.000015                  0.01
#
#                            param_pca__n_components  \
# param_pca__n_components
# 4                       7                        4
# 10                      1                       10
# 20                      2                       20
# 30                      10                      30
# 40                      18                      40
# 50                      12                      50
# 64                      13                      64
#
#                                                                        params  \
# param_pca__n_components
# 4                       7   {'logistic__alpha': 0.01, 'pca__n_components': 4}
# 10                      1   {'logistic__alpha': 0.0001, 'pca__n_components...
# 20                      2   {'logistic__alpha': 0.0001, 'pca__n_components...
# 30                      10  {'logistic__alpha': 0.01, 'pca__n_components':...
# 40                      18  {'logistic__alpha': 1.0, 'pca__n_components': 40}
# 50                      12  {'logistic__alpha': 0.01, 'pca__n_components':...
# 64                      13  {'logistic__alpha': 0.01, 'pca__n_components':...
#
#                             split0_test_score  split1_test_score  \
# param_pca__n_components
# 4                       7            0.730556           0.663889
# 10                      1            0.913889           0.841667
# 20                      2            0.919444           0.877778
# 30                      10           0.927778           0.891667
# 40                      18           0.938889           0.886111
# 50                      12           0.925000           0.894444
# 64                      13           0.922222           0.891667
#
#                             split2_test_score  split3_test_score  \
# param_pca__n_components
# 4                       7            0.732591           0.738162
# 10                      1            0.894150           0.910864
# 20                      2            0.908078           0.941504
# 30                      10           0.924791           0.955432
# 40                      18           0.919220           0.961003
# 50                      12           0.947075           0.944290
# 64                      13           0.949861           0.947075
#
#                             split4_test_score  mean_test_score  \
# param_pca__n_components
# 4                       7            0.690808         0.711201
# 10                      1            0.832869         0.878688
# 20                      2            0.885794         0.906520
# 30                      10           0.866295         0.913193
# 40                      18           0.866295         0.914304
# 50                      12           0.863510         0.914864
# 64                      13           0.866295         0.915424
#
#                             std_test_score  rank_test_score
# param_pca__n_components
# 4                       7         0.029029               25
# 10                      1         0.034593               16
# 20                      2         0.023018               13
# 30                      10        0.030965                4
# 40                      18        0.034377                3
# 50                      12        0.031813                2
# 64                      13        0.032286                1
