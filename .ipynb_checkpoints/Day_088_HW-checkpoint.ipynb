# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def on_train_begin(self,epoch,logs = {}):
        record_items = ['val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp','val_tn']
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)

    def on_epoch_end(self,epoch,logs = {},thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_tp"] = sum(y_true*y_pred)
        logs["val_tn"] = sum((y_true==0) & (y_pred==0))
        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.2246 - accuracy: 0.2677 - val_loss: 2.1548 - val_accuracy: 0.2209
# Epoch 2/25
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.7701 - accuracy: 0.3848 - val_loss: 2.0122 - val_accuracy: 0.2635
# Epoch 3/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.6395 - accuracy: 0.4263 - val_loss: 1.8561 - val_accuracy: 0.3522
# Epoch 4/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.5626 - accuracy: 0.4537 - val_loss: 1.7188 - val_accuracy: 0.4064
# Epoch 5/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.5104 - accuracy: 0.4704 - val_loss: 1.6311 - val_accuracy: 0.4324
# Epoch 6/25
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.4655 - accuracy: 0.4877 - val_loss: 1.5950 - val_accuracy: 0.4387
# Epoch 7/25
# 50000/50000 [==============================] - 2s 46us/step - loss: 1.4267 - accuracy: 0.5007 - val_loss: 1.5522 - val_accuracy: 0.4574
# Epoch 8/25
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.3942 - accuracy: 0.5135 - val_loss: 1.5248 - val_accuracy: 0.4651
# Epoch 9/25
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3635 - accuracy: 0.5249 - val_loss: 1.5100 - val_accuracy: 0.4650
# Epoch 10/25
# 50000/50000 [==============================] - 2s 48us/step - loss: 1.3365 - accuracy: 0.5360 - val_loss: 1.4947 - val_accuracy: 0.4716
# Epoch 11/25
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.3101 - accuracy: 0.5453 - val_loss: 1.4857 - val_accuracy: 0.4758
# Epoch 12/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.2853 - accuracy: 0.5527 - val_loss: 1.4842 - val_accuracy: 0.4731
# Epoch 13/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.2644 - accuracy: 0.5623 - val_loss: 1.4707 - val_accuracy: 0.4814
# Epoch 14/25
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.2423 - accuracy: 0.5691 - val_loss: 1.4657 - val_accuracy: 0.4842
# Epoch 15/25
# 50000/50000 [==============================] - 2s 49us/step - loss: 1.2206 - accuracy: 0.5771 - val_loss: 1.4685 - val_accuracy: 0.4823
# Epoch 16/25
# 50000/50000 [==============================] - 2s 47us/step - loss: 1.2014 - accuracy: 0.5844 - val_loss: 1.4571 - val_accuracy: 0.4876
# Epoch 17/25
# 50000/50000 [==============================] - 2s 45us/step - loss: 1.1820 - accuracy: 0.5917 - val_loss: 1.4432 - val_accuracy: 0.4939
# Epoch 18/25
# 50000/50000 [==============================] - 2s 44us/step - loss: 1.1635 - accuracy: 0.5988 - val_loss: 1.4458 - val_accuracy: 0.4936
# Epoch 19/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1453 - accuracy: 0.6052 - val_loss: 1.4426 - val_accuracy: 0.4940
# Epoch 20/25
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.1271 - accuracy: 0.6130 - val_loss: 1.4466 - val_accuracy: 0.4977
# Epoch 21/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.1091 - accuracy: 0.6205 - val_loss: 1.4369 - val_accuracy: 0.4953
# Epoch 22/25
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.0928 - accuracy: 0.6248 - val_loss: 1.4490 - val_accuracy: 0.4940
# Epoch 23/25
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.0763 - accuracy: 0.6301 - val_loss: 1.4394 - val_accuracy: 0.4973
# Epoch 24/25
# 50000/50000 [==============================] - 2s 42us/step - loss: 1.0588 - accuracy: 0.6396 - val_loss: 1.4572 - val_accuracy: 0.4959
# Epoch 25/25
# 50000/50000 [==============================] - 2s 43us/step - loss: 1.0440 - accuracy: 0.6438 - val_loss: 1.4420 - val_accuracy: 0.4987

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()

# %%
! jupyter nbconvert --to html Day_088_HW.ipynb Day_088_CB_CustomizedCallbacks.ipynb
# Out:
# [NbConvertApp] Converting notebook Day_088_HW.ipynb to html
# [NbConvertApp] Writing 375234 bytes to Day_088_HW.html
# [NbConvertApp] Converting notebook Day_088_CB_CustomizedCallbacks.ipynb to html
# [NbConvertApp] Writing 438837 bytes to Day_088_CB_CustomizedCallbacks.html
