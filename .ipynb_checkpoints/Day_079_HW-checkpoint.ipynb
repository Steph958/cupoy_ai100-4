# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape,output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 0.01
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = [0.95,0.05]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for mom in MOMENTUM:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with momentum = %.6f" % (mom))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    if mom == 0.95:
        nesterov=True
        optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=nesterov, momentum=mom)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
        model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]
    
        exp_name_tag = f"exp-mom-{mom}-nesterov-{nesterov}"
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
        
        nesterov=False
        optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=nesterov, momentum=mom)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
        model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]
    
        exp_name_tag = f"exp-mom-{mom}-nesterov-{nesterov}"
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
    else:
        optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=mom)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
        model.fit(x_train, y_train, 
                  epochs=EPOCHS, 
                  batch_size=BATCH_SIZE, 
                  validation_data=(x_test, y_test), 
                  shuffle=True)
        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]
        exp_name_tag = f"exp-mom-{mom}-nesterov-{nesterov}"
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
# Out:
# Experiment with momentum = 0.950000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.8349 - accuracy: 0.3431 - val_loss: 1.6444 - val_accuracy: 0.4123
# Epoch 2/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.6118 - accuracy: 0.4297 - val_loss: 1.6233 - val_accuracy: 0.4089
# Epoch 3/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.5148 - accuracy: 0.4631 - val_loss: 1.6833 - val_accuracy: 0.4129
# Epoch 4/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.4558 - accuracy: 0.4843 - val_loss: 1.4794 - val_accuracy: 0.4729
# Epoch 5/50
# 50000/50000 [==============================] - 5s 105us/step - loss: 1.3984 - accuracy: 0.5047 - val_loss: 1.5080 - val_accuracy: 0.4673
# Epoch 6/50
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.3637 - accuracy: 0.5165 - val_loss: 1.4555 - val_accuracy: 0.4775
# Epoch 7/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 1.3242 - accuracy: 0.5312 - val_loss: 1.4559 - val_accuracy: 0.4821
# Epoch 8/50
# 50000/50000 [==============================] - 5s 102us/step - loss: 1.2899 - accuracy: 0.5415 - val_loss: 1.4019 - val_accuracy: 0.5092
# Epoch 9/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 1.2526 - accuracy: 0.5557 - val_loss: 1.3832 - val_accuracy: 0.5132
# Epoch 10/50
# 50000/50000 [==============================] - 6s 113us/step - loss: 1.2244 - accuracy: 0.5629 - val_loss: 1.3615 - val_accuracy: 0.5229
# Epoch 11/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 1.1977 - accuracy: 0.5727 - val_loss: 1.3912 - val_accuracy: 0.5138
# Epoch 12/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.1672 - accuracy: 0.5832 - val_loss: 1.3550 - val_accuracy: 0.5252
# Epoch 13/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 1.1410 - accuracy: 0.5945 - val_loss: 1.3492 - val_accuracy: 0.5264
# Epoch 14/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.1109 - accuracy: 0.6046 - val_loss: 1.3735 - val_accuracy: 0.5189
# Epoch 15/50
# 50000/50000 [==============================] - 5s 100us/step - loss: 1.0870 - accuracy: 0.6129 - val_loss: 1.3759 - val_accuracy: 0.5250
# Epoch 16/50
# 50000/50000 [==============================] - 5s 97us/step - loss: 1.0571 - accuracy: 0.6247 - val_loss: 1.3159 - val_accuracy: 0.5473
# Epoch 17/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.0349 - accuracy: 0.6313 - val_loss: 1.3540 - val_accuracy: 0.5336
# Epoch 18/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.0063 - accuracy: 0.6407 - val_loss: 1.3635 - val_accuracy: 0.5327
# Epoch 19/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.9880 - accuracy: 0.6471 - val_loss: 1.4305 - val_accuracy: 0.5200
# Epoch 20/50
# 50000/50000 [==============================] - 5s 95us/step - loss: 0.9652 - accuracy: 0.6556 - val_loss: 1.3717 - val_accuracy: 0.5298
# Epoch 21/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.9326 - accuracy: 0.6674 - val_loss: 1.4045 - val_accuracy: 0.5340
# Epoch 22/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.9050 - accuracy: 0.6769 - val_loss: 1.4221 - val_accuracy: 0.5307
# Epoch 23/50
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.8894 - accuracy: 0.6827 - val_loss: 1.4946 - val_accuracy: 0.5098
# Epoch 24/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.8672 - accuracy: 0.6900 - val_loss: 1.3965 - val_accuracy: 0.5373
# Epoch 25/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.8328 - accuracy: 0.7044 - val_loss: 1.4926 - val_accuracy: 0.5316
# Epoch 26/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.8135 - accuracy: 0.7081 - val_loss: 1.4435 - val_accuracy: 0.5326
# Epoch 27/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.7948 - accuracy: 0.7143 - val_loss: 1.5584 - val_accuracy: 0.5283
# Epoch 28/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.7755 - accuracy: 0.7231 - val_loss: 1.4520 - val_accuracy: 0.5416
# Epoch 29/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.7509 - accuracy: 0.7300 - val_loss: 1.4958 - val_accuracy: 0.5385
# Epoch 30/50
# 50000/50000 [==============================] - 5s 92us/step - loss: 0.7279 - accuracy: 0.7398 - val_loss: 1.5495 - val_accuracy: 0.5388
# Epoch 31/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.7085 - accuracy: 0.7473 - val_loss: 1.6253 - val_accuracy: 0.5129
# Epoch 32/50
# 50000/50000 [==============================] - 5s 99us/step - loss: 0.6899 - accuracy: 0.7532 - val_loss: 1.5932 - val_accuracy: 0.5299
# Epoch 33/50
# 50000/50000 [==============================] - 5s 90us/step - loss: 0.6656 - accuracy: 0.7622 - val_loss: 1.6834 - val_accuracy: 0.5156
# Epoch 34/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.6402 - accuracy: 0.7698 - val_loss: 1.6050 - val_accuracy: 0.5393
# Epoch 35/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.6228 - accuracy: 0.7762 - val_loss: 1.6722 - val_accuracy: 0.5277
# Epoch 36/50
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.5902 - accuracy: 0.7891 - val_loss: 1.7618 - val_accuracy: 0.5291
# Epoch 37/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5763 - accuracy: 0.7929 - val_loss: 1.6911 - val_accuracy: 0.5417
# Epoch 38/50
# 50000/50000 [==============================] - 5s 91us/step - loss: 0.5566 - accuracy: 0.7999 - val_loss: 1.7467 - val_accuracy: 0.5349
# Epoch 39/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5378 - accuracy: 0.8041 - val_loss: 1.8270 - val_accuracy: 0.5223
# Epoch 40/50
# 50000/50000 [==============================] - 5s 98us/step - loss: 0.5145 - accuracy: 0.8148 - val_loss: 1.8643 - val_accuracy: 0.5257
# Epoch 41/50
# 50000/50000 [==============================] - 5s 93us/step - loss: 0.5015 - accuracy: 0.8206 - val_loss: 1.8755 - val_accuracy: 0.5262
# Epoch 42/50
# 50000/50000 [==============================] - 5s 96us/step - loss: 0.4820 - accuracy: 0.8270 - val_loss: 1.9506 - val_accuracy: 0.5241
# Epoch 43/50
# 50000/50000 [==============================] - 5s 101us/step - loss: 0.4641 - accuracy: 0.8344 - val_loss: 2.2334 - val_accuracy: 0.4962
# Epoch 44/50
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.4598 - accuracy: 0.8334 - val_loss: 2.2682 - val_accuracy: 0.5065
# Epoch 45/50
# 50000/50000 [==============================] - 5s 106us/step - loss: 0.4357 - accuracy: 0.8436 - val_loss: 2.1200 - val_accuracy: 0.5267
# Epoch 46/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.4219 - accuracy: 0.8477 - val_loss: 2.0542 - val_accuracy: 0.5334
# Epoch 47/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.4055 - accuracy: 0.8546 - val_loss: 2.1433 - val_accuracy: 0.5284
# Epoch 48/50
# 50000/50000 [==============================] - 5s 94us/step - loss: 0.3895 - accuracy: 0.8607 - val_loss: 2.2339 - val_accuracy: 0.5192
# Epoch 49/50
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.3831 - accuracy: 0.8632 - val_loss: 2.2467 - val_accuracy: 0.5117
# Epoch 50/50
# 50000/50000 [==============================] - 4s 90us/step - loss: 0.3681 - accuracy: 0.8676 - val_loss: 2.5907 - val_accuracy: 0.5046
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-62924be905ae> in <module>
#      22         valid_acc = model.history.history["val_accuracy"]
#      23
# ---> 24         exp_name_tag = f"exp-mom-{mom}-nesterov-{nesterov}"
#      25         results[exp_name_tag] = {'train-loss': train_loss,
#      26                                  'valid-loss': valid_loss,
#
# NameError: name 'nesterov' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
# !jupyter nbconvert --to html Day_079_HW.ipynb Day_079_LearningRateEffect.ipynb
